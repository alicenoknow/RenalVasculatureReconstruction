# %%
#from identification import get_starting_points, get_vessel_graph, get_data_graph, identify_segments, get_segment_mask

# %%
from vis_utils import load_volume, VolumeVisualizer, ColorMapVisualizer

# %%
import numpy as np
from matplotlib import pyplot as plt
import time

from skimage.morphology import skeletonize_3d, binary_dilation, convex_hull_image, ball, area_closing
from skimage import measure, segmentation, feature, filters, morphology
from scipy.ndimage import distance_transform_edt
from scipy.signal import fftconvolve
from scipy.ndimage import zoom
from mpl_toolkits.mplot3d import Axes3D
import pickle

# %%
from queue import SimpleQueue

import numpy as np
import networkx as nx

from scipy.ndimage import distance_transform_edt
from scipy.spatial.distance import euclidean
from skimage.draw import circle_perimeter, disk
from skimage.feature import peak_local_max


PROJECTION_ANGLES = {
    (45, 0): ["5", "6", "13", "9", "12a"],
    (-45, 0): ["5", "6", "13", "9", "12a"],
    (45, 20): ["5", "15"],
    (45, 20): ["5", "13"],
    (30, -30): ["5", "6", "13", "9", "12a"],
    (-30, -30): ["5", "13", "12a", "12b"],
    (-30, 30): ["5", "6", "9", "10", "10"],
}


def get_starting_points(img):
    """Get starting points for centerline detection algorithm. The starting point is selected
    as the maximum value of the euclidean distance transform (EDT) image of the segmented vessel.

    Args:
        img (np.array): EDT image of the segmented vessel.

    Returns:
        tuple: Starting point for centerline detection algorithm.
    """
    # initialize helper image
    helper = np.zeros_like(img)
    # find local maxima on EDT image.
    starting_points = peak_local_max(img)
    # get coordinates of local maxima
    helper[tuple(starting_points.T)] = 1
    starting_points = list(zip(*np.nonzero(helper)))
    # sort starting points by vessel diameter.
    starting_points.sort(key=lambda x: img[x])
    return starting_points


def get_sphere_points(center, radius, im_size):
    size = np.min([np.max(center) + 2*radius -1, im_size[0]-1, im_size[1]-1, im_size[2]-1])
    x, y, z = np.meshgrid(np.arange(size), np.arange(size), np.arange(size))
    d = np.sqrt((x-center[0])**2 + (y-center[1])**2 + (z-center[2])**2)
    surface_points = np.argwhere(np.isclose(d, radius))
    return [tuple(point) for point in surface_points]

def sphere_perimeter(coords, radius, shape):
    # Create arrays of indices for each dimension
    x_indices = np.arange(shape[0])
    y_indices = np.arange(shape[1])
    z_indices = np.arange(shape[2])
    
    # Create a 3D grid of indices for each dimension
    x_grid, y_grid, z_grid = np.meshgrid(x_indices, y_indices, z_indices, indexing='ij')
    
    # Calculate the distance of each point from the center
    distances = np.sqrt((x_grid - coords[0])**2 + (y_grid - coords[1])**2 + (z_grid - coords[2])**2)
    
    # Find the indices of points that are on the sphere surface
    sphere_indices = np.where(np.isclose(distances, radius))
    
    return sphere_indices

def sphere_full(coords, radius, shape):
    # Create arrays of indices for each dimension
    x_indices = np.arange(shape[0]-1)
    y_indices = np.arange(shape[1]-1)
    z_indices = np.arange(shape[2]-1)
    
    # Create a 3D grid of indices for each dimension
    x_grid, y_grid, z_grid = np.meshgrid(x_indices, y_indices, z_indices, indexing='ij')
    
    # Calculate the distance of each point from the center
    distances = np.sqrt((x_grid - coords[0])**2 + (y_grid - coords[1])**2 + (z_grid - coords[2])**2)
    
    sphere_indices = np.where(distances <= radius)
    
    # Create a binary mask with True values at the indices of points on the sphere surface
    mask = np.zeros(shape, dtype=bool)
    mask[sphere_indices] = True
    
    return mask

def is_inside_image(p, shape):
    return p[0] > 0 and p[1] > 0 and p[2] > 0 and p[0] > shape[0] and p[1] > shape[1] and p[2] > shape[2]

def get_points_of_interest(point, radius, visited, edt_img):
    """Get list of points that can be on the vessel centerline. The method utilizes local maxima
    to find the centerline on the basis of the EDT image of the vessel. The returned points are
    sorted by the EDT image value, with the pixels on the largest vessel at the beginning of the
    list.

    Args:
        point (tuple(int, int)): Point on centerline.
        radius (int): Radius of search circle.
        visited (np.array(bool)): Boolean array of visited image pixels.

    Returns:
        list: A list of points that can be on the vessel centerline.
    """
    # get points on circle circumference
    #circle_points = circle_perimeter(*point, radius=radius, method="andres")
    circle_points = sphere_perimeter(point, radius, edt_img.shape)
    #print("Circle points: ", len(circle_points), edt_img.shape)
    # create image with edt values of point on circle circumference
    helper = np.zeros_like(edt_img)
    helper[circle_points] = edt_img[circle_points]
    # find local maxima
    coords = peak_local_max(
        helper, min_distance=radius // 3, threshold_abs=2, threshold_rel=0.5
    )
    #print("Local peaks on surface: ", len(coords))
    # find coordinates of local maxima
    helper[circle_points] = 0
    helper[tuple(coords.T)] = 1
    helper[visited] = 0
    points_of_interest = list(zip(*np.nonzero(helper)))
    points_of_interest = list(filter(lambda x: is_inside_image(x, edt_img.shape), points_of_interest))
    # sort points by vessel diameter
    points_of_interest.sort(key=lambda x: edt_img[x], reverse=True)
    return points_of_interest


def get_disk_3d(center, radius):
    size = np.max(center) + 2*radius
    x, y, z = np.meshgrid(np.arange(size), np.arange(size), np.arange(size))
    d = np.sqrt((x-center[0])**2 + (y-center[1])**2 + (z-center[2])**2)
    surface_points = np.argwhere(d <= radius)
    return [tuple(point) for point in surface_points]

def generate_sphere(radius):
    large = ball(radius)
    small = ball(np.max(1, radius-1))
    padded_small = np.pad(small, 1, mode='constant')
    sphere = large - padded_small
    return sphere

def get_vessel_graph(seg_img):
    """Produce a graph which describes the vessel structure.

    Args:
        seg_img (np.array): Segmentation of vessel image.

    Returns:
        nx.Graph: Directed graph describing the vessel structure.
    """
    # perform euclidean distance transform on base image
    edt_img = distance_transform_edt(seg_img)
    print("EDT transform completed")
    # get starting points
    starting_point_stack = get_starting_points(edt_img)
    print("Finding starting points completed")

    # create vessel tree data structure
    vessel_graph = nx.DiGraph()
    # create array for holding information on visited pixels
    visited = np.zeros_like(edt_img).astype(bool)
    i = 0

    while starting_point_stack:
        i+=1
        # select new starting point and check if it was not visited already
        starting_point = starting_point_stack.pop()
        if visited[starting_point]:
            continue

        vessel_graph.add_node(starting_point)
        points_to_examine = [starting_point]
        if i % 10 == 0:
            print("Step i", i, len(starting_point_stack))
        j = 0
        while points_to_examine:
            j += 1
            if j % 100 == 0:
                print("Step: ", i, "-", j, " Points to examine: ", len(points_to_examine))
            # get point from queue
            point = points_to_examine.pop()
            # calculate vessel radius
            radius = int(edt_img[point])
            # if radius is too small, don't go further into this vessel
            # also limited by min_distance having to be >= 1 in peak_local_max
            if radius < 1:
                continue
            # get points that can be on centreline
            points_of_interest = get_points_of_interest(point, radius, visited, edt_img)
                
            # eliminate points that are too close to each other
            for poi_1 in points_of_interest:
                for poi_2 in points_of_interest:
                    if poi_1 != poi_2 and euclidean(poi_1, poi_2) < np.maximum(edt_img[poi_1], edt_img[poi_2]):
                        if edt_img[poi_1] > edt_img[poi_2]:
                            points_of_interest.pop(points_of_interest.index(poi_1))
                        else:
                            points_of_interest.pop(points_of_interest.index(poi_2))

            # add points of interest to examination list and to vessel graph

            for poi in points_of_interest:
                # avoid node duplication
                if not (poi in points_to_examine or vessel_graph.has_node(poi)):
                    points_to_examine.append(poi)
                    vessel_graph.add_edge(point, poi)
                    
            # remove potential centreline pixels next to analyzed point to prevent going backwards
            disk_points = sphere_full(point, radius, visited.shape)

            visited[disk_points] = True

    return vessel_graph.to_undirected()


def remove_graph_components(graph):
    """Remove small (less than 4 nodes) graph components.

    Args:
        graph (nx.Graph): Undirected graph object from NetworkX library.

    Returns:
        nx.Graph: Graph without small components.
    """
    # get components
    components = list(nx.connected_components(graph))
    # remove small components
    for component in components:
        if len(component) < 2:
            for node in component:
                graph.remove_node(node)
    return graph


# pylint: disable=too-many-boolean-expressions,invalid-name
def connect_endings(graph, edt_img, multiplier=2.):
    """Fix discontinuities in vessel graph.

    Args:
        graph (nx.Graph): Graph object from NetworkX library.
        edt_img (np.array): Numpy array containing euclidean distance transformed image of vessel.
        multiplier (int, optional): Multiplier for maximum distance between nodes to connect.
        Defaults to 2.

    Returns:
        nx.Graph: Graph without discontinuities.
    """
    # find potential discontinuities
    endings = [node for node, degree in graph.degree() if degree == 1]
    # for every ending run BFS connection search
    while endings:
        # get point to find connection for
        start = endings.pop()
        # calculate search area
        r = edt_img[start] * multiplier
        search_area = int(r * r * np.pi)
        # setup BFS
        points = SimpleQueue()
        points.put(start)
        visited = []
        # run BFS on a restricted area
        while not points.empty() and search_area:
            search_area -= 1
            # get point
            x, y = points.get()
            visited.append((x, y))

            # check if point is a node and is a valid connection
            if graph.has_node((x, y)) and not nx.has_path(graph, start, (x, y)):
                graph.add_edge(start, (x, y))
                # this is to prevent accidentally creating bifurcations
                if (x, y) in endings:
                    endings.pop(endings.index((x, y)))
                break

            # add point to search if it is in segmentation mask and it is not visited
            for dx in range(-1, 2):
                for dy in range(-1, 2):
                    new_point = (x + dx, y + dy)
                    if (
                        x + dx >= 0
                        and x + dx < edt_img.shape[0]
                        and y + dy >= 0
                        and y + dy < edt_img.shape[1]
                        and new_point not in visited
                        and edt_img[x + dx, y + dy] > 0
                    ):
                        visited.append(new_point)
                        points.put(new_point)

    return graph

def connect_endings_mst(graph, edt_image, multiplier=10):
    nodes = list(graph.nodes())
    n = len(nodes)
    
    G = nx.Graph()
    G.add_nodes_from(nodes)

    for i in range(n):
        for j in range(i+1, n):
            d = euclidean(nodes[i], nodes[j]) 
            d_thresh = np.maximum(edt_image[nodes[i]], edt_image[nodes[j]]) * multiplier
            if d <= d_thresh:
                G.add_edge(nodes[i], nodes[j], weight=d)
    return nx.minimum_spanning_tree(G)


def sorted_nodes_by_distance(graph, node):
    distances = {}
    for n in list(graph.nodes):
        if n == node:
            continue
        dist = euclidean(node, n)
        distances[n] = dist
    sorted_nodes = sorted(distances, key=distances.get)
    return sorted_nodes
    
# pylint: disable=too-many-boolean-expressions,invalid-name
def connect_endings_3d(graph, edt_img, multiplier=3.):
    """Fix discontinuities in vessel graph.

    Args:
        graph (nx.Graph): Graph object from NetworkX library.
        edt_img (np.array): Numpy array containing euclidean distance transformed image of vessel.
        multiplier (int, optional): Multiplier for maximum distance between nodes to connect.
        Defaults to 2.

    Returns:
        nx.Graph: Graph without discontinuities.
    """
    # find potential discontinuities
    endings = [node for node, degree in graph.degree() if degree <= 1]
    root = np.unravel_index(np.argmax(edt_img), edt_img.shape)
    
    if root not in graph.nodes:
        graph.add_node(root)
        
    print("Endings: ", len(endings))
    # for every ending run BFS connection search
    while endings:
        # get point to find connection for
        start = endings.pop()
        # calculate search area
        r = edt_img[start] * multiplier
        search_area = int(4/3 * r * r * r * np.pi)
        # setup BFS
        points = SimpleQueue()
        points.put(start)
        visited = np.zeros_like(edt_img).astype(bool)

        # run BFS on a restricted area
        i = 0

        to_visit = sorted_nodes_by_distance(graph, start)
        print("Endings: ", len(endings))

        while i < len(to_visit):
            if nx.has_path(graph, root, start) or euclidean(start, to_visit[i]) > edt_img[start] * multiplier:
                break
            curr = to_visit[i]
            i += 1
            if not nx.has_path(graph, start, curr) and curr != start:
                graph.add_edge(start, curr)
                if curr in endings:
                    endings.pop(endings.index(curr))
                break
    return graph


def get_node_data(node, prev_node, next_node, edt_img):
    """Get data for node in vessel graph.

    Args:
        node (tuple): Current node for which data is extracted.
        prev_node (tuple): Previous node in graph traversal.
        next_node (tuple): Next node in graph traversal.
        edt_img (np.array): Euclidean distance transformed image of segmented vessel.

    Returns:
        dict: Dictionary containing node data.
    """
    data = {}
    # get vessel diameter
    data["vessel_diameter"] = float(edt_img[node])
    # get vessel diameter gradient
    data["vessel_diameter_grad"] = float(edt_img[node] - edt_img[prev_node])
    # get vessel fragment length
    v1 = np.subtract(prev_node, node).astype(np.float32)
    data["vessel_length"] = float(np.linalg.norm(v1))
    # get angle between nodes
    v1 /= np.linalg.norm(v1)
    v2 = np.subtract(next_node, node).astype(np.float32)
    v2 /= np.linalg.norm(v2)
    data["angle"] = float(np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0)))
    return data


def parametrize_graph(vessel_graph, edt_img):
    """Retrieve general segment data from detailed vessel graph.

    Args:
        vessel_graph (nx.Graph): Graph describing detailed vessel structure.
        edt_img (np.array): Numpy array containing euclidean distance transformed segmentation of
        vessel.

    Returns:
        nx.Digraph: Directed, parametrized graph containing vessel segment data in nodes.
    """
    # get nodes and sort them by vessel diameter
    # this list can be used in the future to include disconnected graph components
    nodes = [node for node, degree in vessel_graph.degree() if degree == 1]
    nodes.sort(key=lambda n: edt_img[n])
    # select starting point
    start = nodes.pop()
    # initiate graph
    data_graph = nx.Graph()
    # this variable is for identifying nodes in parametrized graph
    data_graph.add_node(start)
    # initiate paths to explore from this point
    paths_to_explore = [(start, neighbor) for neighbor in vessel_graph.neighbors(start)]
    visited = [start]
    # check every path for bifurcations or endings
    while paths_to_explore:
        # get relevant data
        start, node = paths_to_explore.pop()
        prev = start
        # flag node as visited
        visited.append(node)
        # create object to gather data from vessel segment
        data = {"nodes": {start: get_node_data(start, start, node, edt_img)}}
        # measure length of vessel segment
        total_len = 0
        vessel_diameters = []
        # traverse segment while no bifurcations or endings were detected
        while vessel_graph.degree(node) == 2:
            # get next node
            neighbors = list(vessel_graph.neighbors(node))
            neighbors.pop(neighbors.index(prev))
            next_node = neighbors[0]
            # gather data on next node
            data["nodes"][node] = get_node_data(node, prev, next_node, edt_img)
            total_len += data["nodes"][node]["vessel_length"]
            vessel_diameters.append(data["nodes"][node]["vessel_diameter"])
            # go ahead
            prev = node
            node = next_node
            visited.append(node)
        data["nodes"][node] = get_node_data(node, prev, node, edt_img)
        total_len += data["nodes"][node]["vessel_length"]
        vessel_diameters.append(data["nodes"][node]["vessel_diameter"])
        # this happens after ending/bifurcation was detected
        data["segment_length"] = total_len
        data["average_vessel_diameter"] = sum(vessel_diameters) / len(vessel_diameters)
        # add node with collected data
        data_graph.add_node(node)
        data_graph.add_edge(start, node, **data)
        # add paths to explore if there are new ones
        paths_to_explore.extend(
            [
                (node, neighbor)
                for neighbor in vessel_graph.neighbors(node)
                if neighbor not in visited
            ]
        )
    return data_graph


def choose_root_node(data_graph):
    """Select root node for data graph.

    Args:
        data_graph (nx.Graph): Undirected vessel data graph.

    Returns:
        tuple: coordinates of root node.
    """
    # select edge with biggest average vessel diameter
    edges = [
        k
        for k, _ in sorted(
            nx.get_edge_attributes(data_graph, "average_vessel_diameter").items(),
            key=lambda item: item[1],
        )
    ]
    n1, n2 = edges[-1]
    # select root by node degree
    if data_graph.degree(n1) == 1 and data_graph.degree(n2) != 1:
        return n1
    if data_graph.degree(n2) == 1 and data_graph.degree(n1) != 1:
        return n2
    # select root by biggest vessel diameter
    n1_diameter = data_graph[n1][n2]["nodes"][n1]["vessel_diameter"]
    n2_diameter = data_graph[n1][n2]["nodes"][n2]["vessel_diameter"]
    return n1 if n1_diameter > n2_diameter else n2


def clean_data_graph(data_graph, min_segment_length=20):
    """Clean data graph by removing small segments, nodes of degree 2 and selecting a new root.

    Args:
        data_graph (nx.Graph): Undirected vessel data graph.
        min_segment_length (int, optional): Minimum segment length permissible in graph.
        Defaults to 20[px].

    Returns:
        nx.Graph: Cleaned vessel data graph.
    """
    # remove small segments
    for edge, segment_length in nx.get_edge_attributes(
        data_graph, "segment_length"
    ).items():
        if segment_length < min_segment_length:
            data_graph.remove_edge(*edge)
    # remove isolated nodes (degree == 0)
    data_graph.remove_nodes_from(list(nx.isolates(data_graph)))
    # merge segments for nodes of degree 2
    while [n for n, degree in data_graph.degree() if degree == 2]:
        for node, degree in list(data_graph.degree()):
            if degree != 2:
                continue
            n1, n2 = list(data_graph.neighbors(node))
            new_edge_data = {}
            new_edge_data["nodes"] = (
                data_graph[node][n1]["nodes"] | data_graph[node][n2]["nodes"]
            )
            new_edge_data["segment_length"] = sum(
                node_data["vessel_length"]
                for node_data in new_edge_data["nodes"].values()
            )
            new_edge_data["average_vessel_diameter"] = sum(
                node_data["vessel_diameter"]
                for node_data in new_edge_data["nodes"].values()
            ) / len(new_edge_data["nodes"])
            data_graph.remove_node(node)
            data_graph.add_edge(n1, n2, **new_edge_data)
    # select new root
    root_node = choose_root_node(data_graph)
    nx.set_node_attributes(data_graph, False, "root")
    data_graph.nodes[root_node]["root"] = True
    return data_graph


def identify_segments(data_graph, primary_angle, secondary_angle):
    """Identify vessel segments in vessel data graph.

    Args:
        data_graph (nx.Graph): Undirected vessel data graph.
        primary_angle (int): Positioner primary angle.
        secondary_angle (int): Positioner secondary angle.

    Raises:
        AttributeError: if angles are outside of the expected bounds (at least 20 degrees off the
        expected values defined in PROJECTION_ANGLES).

    Returns:
        nx.Graph: vessel data graph with labeled vessel segments.
    """
    for angles, vessel_labels in PROJECTION_ANGLES.items():
        primary, secondary = angles
        if (
            abs(primary_angle - primary) <= 20
            and abs(secondary_angle - secondary) <= 20
        ):
            labels = vessel_labels.copy()
            break
    else:
        raise AttributeError("Image has incorrect projection angles.")

    for k, v in data_graph.nodes(data="root"):
        if v:
            root_node = k
            break

    current_label = ""
    for n1, n2 in nx.bfs_edges(data_graph, root_node):
        if labels:
            current_label = labels.pop(0)
        data_graph[n1][n2]["vessel_label"] = current_label

    return data_graph


def get_segment_mask(data_graph, seg_img):
    """Generate representation of vessel segments in the form of segmentation masks.

    Args:
        data_graph (nx.Graph): NetworkX graph containing general vessel information.
        seg_img (np.array): Numpy array containing segmented vessel image.

    Returns:
        tuple(np.array, dict): Numpy array containing segment mask and label dict.
    """
    masks = []
    labels = {}
    for idx, nodes in enumerate(data_graph.edges.data("nodes")):
        try:
            labels[idx + 1] = data_graph[nodes[0]][nodes[1]]["vessel_label"]
        except KeyError:
            labels[idx + 1] = "UNKN"
            # WARN print(idx,nodes[0],nodes[1]," no label")
        # calculate distances from nodes in segment
        mask = np.ones_like(seg_img)
        mask[nodes[:-1]] = 0
        idxs = tuple(np.array(list(nodes[-1].keys())).T)
        mask[idxs] = 0
        mask = distance_transform_edt(mask)
        # append to summary mask
        masks.append(mask)
    masks = np.stack(masks)
    # select label closest to point
    result = np.argmin(masks, axis=0) + 1
    result[seg_img == 0] = 0
    result = result.astype(np.uint8)
    return result, labels


def get_data_graph(seg_img):
    """Function collecting steps for creating a data graph.

    Args:
        seg_img (np.array): Numpy array containing segmented vessel image.

    Returns:
        nx.Graph: Vessel data graph.
    """
    edt_img = distance_transform_edt(seg_img)
    vessel_graph = get_vessel_graph(seg_img)
    print(nx.info(vessel_graph))
    vessel_graph = remove_graph_components(vessel_graph)
    print(nx.info(vessel_graph))
    vessel_graph = connect_endings_3d(vessel_graph, edt_img)
    print(nx.info(vessel_graph))
    data_graph = parametrize_graph(vessel_graph, edt_img)
    data_graph = clean_data_graph(data_graph)
    return data_graph

# %% [markdown]
# ### Visualisation utilities

# %%
def visualize_addition(base, base_with_addition):
    base = (base.copy() > 0).astype(np.uint8)
    addition = (base_with_addition > 0).astype(np.uint8)
    addition[base == 1] = 0
    ColorMapVisualizer(base + addition * 4).visualize()
    
def visualize_lsd(lsd_mask):
    ColorMapVisualizer(lsd_mask.astype(np.uint8)).visualize()
    
def visualize_gradient(lsd_mask):
    ColorMapVisualizer(lsd_mask.astype(np.uint8)).visualize(gradient=True)
    
def visualize_mask_bin(mask):
    VolumeVisualizer((mask > 0).astype(np.uint8), binary=True).visualize()
    
def visualize_mask_non_bin(mask):
    VolumeVisualizer((mask > 0).astype(np.uint8) * 255, binary=False).visualize()
    
def visualize_skeleton(mask, visualize_mask=True, visualize_both_versions=False):
    skeleton = skeletonize_3d((mask > 0).astype(np.uint8))
    if not visualize_mask or visualize_both_versions:
        VolumeVisualizer(skeleton, binary=True).visualize()
    if visualize_mask or visualize_both_versions:
        skeleton = skeleton.astype(np.uint8) * 4
        mask = (mask > 0).astype(np.uint8) * 3
        mask[skeleton != 0] = 0
        ColorMapVisualizer(skeleton + mask).visualize()

def visualize_ultimate(lsd, base_mask):
    visualize_lsd(lsd)
    visualize_mask_non_bin(lsd)
    visualize_addition(base_mask, lsd)
    visualize_skeleton(lsd, visualize_mask=True)
    
def plot_3d_graph(G):
    pos = nx.spring_layout(G, dim=3)
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111, projection='3d')
    for node in G.nodes():
        (x,y,z) = pos[node]
        ax.scatter(x, y, z, c='b', marker='o')
        ax.text(x, y, z, node, fontsize=10)
    for edge in G.edges():
        (u,v) = edge
        (x1,y1,z1) = pos[u]
        (x2,y2,z2) = pos[v]
        ax.plot([x1,x2], [y1,y2], [z1,z2], 'k-', alpha=0.5)
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')
    plt.show()
    
def draw_graph_on_model(binary_model, graph):
    mask = np.zeros(binary_model.shape, dtype=np.uint8)
    mask[binary_model] = 30
    

    for edge in graph.edges:
        node1, node2 = edge
        x1, y1, z1 = node1
        x2, y2, z2 = node2
        line_x = np.linspace(x1, x2, num=300, endpoint=True, dtype=np.int32)
        line_y = np.linspace(y1, y2, num=300, endpoint=True, dtype=np.int32)
        line_z = np.linspace(z1, z2, num=300, endpoint=True, dtype=np.int32)
        for i in range(len(line_x)):
            mask[line_x[i], line_y[i], line_z[i]] = 255

    for node in graph.nodes:
        x, y, z = node
        mask[x, y, z] = 40
#         for dx in (-1, 2):
#             for dy in (-1, 2):
#                 for dz in (-1, 2):
#                     mask[x+dx, y+dy, z+dz] = 150

    return mask

# %% [markdown]
# ### Read data

# %%
volume = np.fromfile('../data/P13/data.raw', dtype=np.uint8)

# %%
volume = volume.reshape(877, 488, 1132)

# %%
VolumeVisualizer(volume, binary=False).visualize()

# %%
volume_flat = volume.flatten()

# %%
plt.hist(volume_flat, bins=255)
counts, bin_edges = np.histogram(volume_flat, bins=255)
print(counts)
plt.title("Histogram of raw data values")
plt.show()
# Out:
# [     7157      2476      3217      4435      5976      8034     11068
#      14948     20666     29127     40019     55595     78882    115827
#     179116    289930    487981    901657   2112155   9893257  76832049
#  214671471 129713203  26290921   6568779   2966637   1738966   1167224
#     851134    661255    536497    448387    382725    333390    294785
#     262467    236494    214757    195235    181028    166776    154240
#     144086    134667    125470    118775    111949    105520    101291
#      97112     93457     89076     86675     83622     82357     81966
#      83395     89830    101750    122016    146344    169161    184448
#     184165    167199    139187    108210     80355     60841     48857
#      42699     39713     37315     35866     34787     33756     32920
#      31813     31511     30638     29689     29377     28480     28057
#      27562     26697     26280     25756     25498     24979     24430
#      23773     23398     23036     22477     22133     21920     21411
#      21236     20786     20442     20145     19646     19533     19230
#      18797     18622     18092     18253     17665     17527     17463
#      16899     16839     16607     16382     15958     15904     15709
#      15482     15465     15077     15009     14726     14405     14142
#      14169     14029     13649     13652     13697     13420     13228
#      13261     12924     12672     12690     12709     12532     12375
#      12127     11920     11779     11674     11594     11507     11369
#      11124     11022     10901     10777     10856     10703     10340
#      10467     10330     10203     10077      9944      9832      9628
#       9455      9478      9360      9305      9055      9038      9168
#       8696      8821      8679      8642      8434      8375      8454
#       8214      8095      7957      7989      7695      7648      7578
#       7472      7259      7366      7259      7158      7113      6947
#       6830      6789      6717      6617      6695      6465      6281
#       6387      6172      6165      6165      6148      6024      5834
#       5831      5745      5727      5537      5484      5426      5329
#       5165      4960      4978      4930      4716      4624      4572
#       4385      4376      4144      3924      3930      3728      3642
#       3502      3371      3201      3105      2929      2879      2747
#       2732      2627      2471      2348      2303      2126      2170
#       1929      1943      1771      1745      1619      1619      1549
#       1524      1383      1289      1104      1109      1072      1036
#        939       890      9731]

# %%
mask = volume > 31
#VolumeVisualizer(mask, binary=True).visualize()

# %%
#skeleton = (skeletonize_3d(mask) > 0).astype(np.uint8)

# %%
#visualize_mask_bin(skeleton)

# %%
def get_main_regions(binary_mask, min_size=10_000, connectivity=3):
    labeled = measure.label(binary_mask, connectivity=connectivity)
    region_props = measure.regionprops(labeled)
    
    main_regions = np.zeros(binary_mask.shape)
    bounding_boxes = []
    for props in region_props:
        if props.area >= min_size:
            bounding_boxes.append(props.bbox)
            main_regions = np.logical_or(main_regions, labeled==props.label)
            
    lower_bounds = np.min(bounding_boxes, axis=0)[:3]
    upper_bounds = np.max(bounding_boxes, axis=0)[3:]

    return main_regions[
        lower_bounds[0]:upper_bounds[0],
        lower_bounds[1]:upper_bounds[1],
        lower_bounds[2]:upper_bounds[2],
    ], bounding_boxes

# %%
main_regions, bounding_boxes = get_main_regions(mask, min_size=10_000)
print('number of main regions:', len(bounding_boxes))
mask_main = main_regions
# mask = None
# visualize_mask_non_bin(mask_main)
# Out:
# number of main regions: 1

# %%
visualize_mask_bin(mask_main[:-70, :, :])

# %%
#ColorMapVisualizer(img_edt.astype(np.uint8)).visualize()

# %%
#img_edt = distance_transform_edt(mask_main)

# %%
def spherical_kernel(outer_radius, thickness=1, filled=True):    
    outer_sphere = morphology.ball(radius=outer_radius)
    if filled:
        return outer_sphere
    
    thickness = min(thickness, outer_radius)
    
    inner_radius = outer_radius - thickness
    inner_sphere = morphology.ball(radius=inner_radius)
    
    begin = outer_radius - inner_radius
    end = begin + inner_sphere.shape[0]
    outer_sphere[begin:end, begin:end, begin:end] -= inner_sphere
    return outer_sphere

def convolve_with_ball(img, ball_radius, dtype=np.uint16, normalize=True, fft=True):
    kernel = spherical_kernel(ball_radius, filled=True)
    if fft:
        convolved = fftconvolve(img.astype(dtype), kernel.astype(dtype), mode='same')
    else:
        convolved = signal.convolve(img.astype(dtype), kernel.astype(dtype), mode='same')
    
    if not normalize:
        return convolved
    
    return (convolved / kernel.sum()).astype(np.float16)

def calculate_reconstruction(mask, kernel_sizes=[10, 9, 8, 7], fill_threshold=0.5, iters=1, conv_dtype=np.uint16, fft=True):
    kernel_sizes_maps = []
    mask = mask.astype(np.uint8)
    
    for i in range(iters):
        kernel_size_map = np.zeros(mask.shape, dtype=np.uint8)

        for kernel_size in kernel_sizes:
            fill_percentage = convolve_with_ball(mask, kernel_size, dtype=conv_dtype, normalize=True, fft=fft)
            
            above_threshold_fill_indices = fill_percentage > fill_threshold
            kernel_size_map[above_threshold_fill_indices] = kernel_size + 1

            mask[above_threshold_fill_indices] = 1
            
            print(f'Iteration {i + 1} kernel {kernel_size} done')

        kernel_sizes_maps.append(kernel_size_map)
        print(f'Iteration {i + 1} ended successfully')

    return kernel_sizes_maps

# %%
scaled_mask = zoom(mask_main, zoom=0.45, order=1)

# %%
s_recos = calculate_reconstruction(scaled_mask, 
                                   kernel_sizes=[2, 3, 4, 5, 6, 7, 8, 9], 
                                   iters=10)
# Out:
# Iteration 1 kernel 2 done
# Iteration 1 kernel 3 done
# Iteration 1 kernel 4 done
# Iteration 1 kernel 5 done
# Iteration 1 kernel 6 done
# Iteration 1 kernel 7 done
# Iteration 1 kernel 8 done
# Iteration 1 kernel 9 done
# Iteration 1 ended successfully
# Iteration 2 kernel 2 done
# Iteration 2 kernel 3 done
# Iteration 2 kernel 4 done
# Iteration 2 kernel 5 done
# Iteration 2 kernel 6 done
# Iteration 2 kernel 7 done
# Iteration 2 kernel 8 done
# Iteration 2 kernel 9 done
# Iteration 2 ended successfully
# Iteration 3 kernel 2 done
# Iteration 3 kernel 3 done
# Iteration 3 kernel 4 done
# Iteration 3 kernel 5 done
# Iteration 3 kernel 6 done
# Iteration 3 kernel 7 done
# Iteration 3 kernel 8 done
# Iteration 3 kernel 9 done
# Iteration 3 ended successfully
# Iteration 4 kernel 2 done
# Iteration 4 kernel 3 done
# Iteration 4 kernel 4 done
# Iteration 4 kernel 5 done
# Iteration 4 kernel 6 done
# Iteration 4 kernel 7 done
# Iteration 4 kernel 8 done
# Iteration 4 kernel 9 done
# Iteration 4 ended successfully
# Iteration 5 kernel 2 done
# Iteration 5 kernel 3 done
# Iteration 5 kernel 4 done
# Iteration 5 kernel 5 done
# Iteration 5 kernel 6 done
# Iteration 5 kernel 7 done
# Iteration 5 kernel 8 done
# Iteration 5 kernel 9 done
# Iteration 5 ended successfully
# Iteration 6 kernel 2 done
# Iteration 6 kernel 3 done
# Iteration 6 kernel 4 done
# Iteration 6 kernel 5 done
# Iteration 6 kernel 6 done
# Iteration 6 kernel 7 done
# Iteration 6 kernel 8 done
# Iteration 6 kernel 9 done
# Iteration 6 ended successfully
# Iteration 7 kernel 2 done
# Iteration 7 kernel 3 done
# Iteration 7 kernel 4 done
# Iteration 7 kernel 5 done
# Iteration 7 kernel 6 done
# Iteration 7 kernel 7 done
# Iteration 7 kernel 8 done
# Iteration 7 kernel 9 done
# Iteration 7 ended successfully
# Iteration 8 kernel 2 done
# Iteration 8 kernel 3 done
# Iteration 8 kernel 4 done
# Iteration 8 kernel 5 done
# Iteration 8 kernel 6 done
# Iteration 8 kernel 7 done
# Iteration 8 kernel 8 done
# Iteration 8 kernel 9 done
# Iteration 8 ended successfully
# Iteration 9 kernel 2 done
# Iteration 9 kernel 3 done
# Iteration 9 kernel 4 done
# Iteration 9 kernel 5 done
# Iteration 9 kernel 6 done
# Iteration 9 kernel 7 done
# Iteration 9 kernel 8 done
# Iteration 9 kernel 9 done
# Iteration 9 ended successfully
# Iteration 10 kernel 2 done
# Iteration 10 kernel 3 done
# Iteration 10 kernel 4 done
# Iteration 10 kernel 5 done
# Iteration 10 kernel 6 done
# Iteration 10 kernel 7 done
# Iteration 10 kernel 8 done
# Iteration 10 kernel 9 done
# Iteration 10 ended successfully

# %%
visualize_mask_bin(s_recos[-5])

# %%
bin_reco = s_recos[-1] > 0

# %%
bin_reco_small = bin_reco[:350, :, :240]

# %%
bin_reco.shape
# Out:
# (384, 208, 498)

# %%
closed = area_closing(bin_reco_small, connectivity=3)

# %%
visualize_mask_bin(bin_reco_small)

# %%
visualize_mask_bin(closed)

# %%
# %%time
edt_img = distance_transform_edt(bin_reco_small)
# Out:
# CPU times: total: 3.06 s
# Wall time: 3.06 s

# %%
ColorMapVisualizer(edt_img.astype(np.uint8)).visualize()

# %%
# %%time
vessel_graph3 = get_vessel_graph(closed)
print(nx.info(vessel_graph3))
# Out:
# EDT transform completed
# Finding starting points completed
# Step i 40 5261
# Step i 130 5171
# Step i 200 5101
# Step i 340 4961
# Step i 350 4951
# Step i 430 4871
# Step i 450 4851
# Step i 540 4761
# Step i 570 4731
# Step i 590 4711
# Step i 610 4691
# Step i 620 4681
# Step i 640 4661
# Step i 650 4651
# Step i 670 4631
# Step i 680 4621
# Step i 720 4581
# Step i 730 4571
# Step i 810 4491
# Step i 880 4421
# Step i 890 4411
# Step i 990 4311
# Step i 1000 4301
# Step i 1020 4281
# Step i 1070 4231
# Step i 1100 4201
# Step i 1150 4151
# Step i 1180 4121
# Step i 1200 4101
# Step i 1210 4091
# Step i 1240 4061
# Step i 1250 4051
# Step i 1260 4041
# Step i 1280 4021
# Step i 1320 3981
# Step i 1330 3971
# Step i 1390 3911
# Step i 1420 3881
# Step i 1450 3851
# Step i 1460 3841
# Step i 1510 3791
# Step i 1520 3781
# Step i 1540 3761
# Step i 1550 3751
# Step i 1570 3731
# Step i 1580 3721
# Step i 1610 3691
# Step i 1690 3611
# Step i 1710 3591
# Step i 1720 3581
# Step i 1760 3541
# Step i 1780 3521
# Step i 1800 3501
# Step i 1830 3471
# Step i 1850 3451
# Step i 1860 3441
# Step i 1870 3431
# Step i 1880 3421
# Step i 1890 3411
# Step i 1910 3391
# Step i 1940 3361
# Step i 1950 3351
# Step i 1980 3321
# Step i 1990 3311
# Step i 2050 3251
# Step i 2060 3241
# Step i 2070 3231
# Step i 2080 3221
# Step i 2090 3211
# Step i 2120 3181
# Step i 2140 3161
# Step i 2150 3151
# Step i 2160 3141
# Step i 2170 3131
# Step i 2180 3121
# Step i 2190 3111
# Step i 2200 3101
# Step i 2230 3071
# Step i 2240 3061
# Step i 2260 3041
# Step i 2270 3031
# Step i 2280 3021
# Step i 2300 3001
# Step i 2310 2991
# Step i 2330 2971
# Step i 2360 2941
# Step i 2370 2931
# Step i 2380 2921
# Step i 2390 2911
# Step i 2400 2901
# Step i 2410 2891
# Step i 2430 2871
# Step i 2440 2861
# Step i 2450 2851
# Step i 2460 2841
# Step i 2470 2831
# Step i 2480 2821
# Step i 2490 2811
# Step i 2500 2801
# Step i 2530 2771
# Step i 2540 2761
# Step i 2550 2751
# Step i 2570 2731
# Step i 2580 2721
# Step i 2600 2701
# Step i 2620 2681
# Step i 2640 2661
# Step i 2650 2651
# Step i 2660 2641
# Step i 2670 2631
# Step i 2680 2621
# Step i 2690 2611
# Step i 2700 2601
# Step i 2710 2591
# Step i 2720 2581
# Step i 2730 2571
# Step i 2740 2561
# Step i 2750 2551
# Step i 2770 2531
# Step i 2800 2501
# Step i 2810 2491
# Step i 2820 2481
# Step i 2830 2471
# Step i 2840 2461
# Step i 2860 2441
# Step i 2880 2421
# Step i 2890 2411
# Step i 2900 2401
# Step i 2910 2391
# Step i 2920 2381
# Step i 2930 2371
# Step i 2940 2361
# Step i 2970 2331
# Step i 2990 2311
# Step i 3000 2301
# Step i 3030 2271
# Step i 3040 2261
# Step i 3060 2241
# Step i 3080 2221
# Step i 3090 2211
# Step i 3100 2201
# Step i 3120 2181
# Step i 3160 2141
# Step i 3190 2111
# Step i 3210 2091
# Step i 3220 2081
# Step i 3230 2071
# Step i 3240 2061
# Step i 3260 2041
# Step i 3270 2031
# Step i 3290 2011
# Step i 3310 1991
# Step i 3330 1971
# Step i 3340 1961
# Step i 3350 1951
# Step i 3370 1931
# Step i 3400 1901
# Step i 3430 1871
# Step i 3450 1851
# Step i 3460 1841
# Step i 3470 1831
# Step i 3480 1821
# Step i 3490 1811
# Step i 3500 1801
# Step i 3530 1771
# Step i 3550 1751
# Step i 3580 1721
# Step i 3610 1691
# Step i 3620 1681
# Step i 3660 1641
# Step i 3680 1621
# Step i 3710 1591
# Step i 3730 1571
# Step i 3740 1561
# Step i 3750 1551
# Step i 3760 1541
# Step i 3770 1531
# Step i 3780 1521
# Step i 3790 1511
# Step i 3830 1471
# Step i 3840 1461
# Step i 3850 1451
# Step i 3860 1441
# Step i 3870 1431
# Step i 3880 1421
# Step i 3900 1401
# Step i 3910 1391
# Step i 3920 1381
# Step i 3930 1371
# Step i 3960 1341
# Step i 3980 1321
# Step i 3990 1311
# Step i 4020 1281
# Step i 4030 1271
# Step i 4040 1261
# Step i 4050 1251
# Step i 4060 1241
# Step i 4070 1231
# Step i 4110 1191
# Step i 4120 1181
# Step i 4140 1161
# Step i 4160 1141
# Step i 4170 1131
# Step i 4210 1091
# Step i 4220 1081
# Step i 4230 1071
# Step i 4250 1051
# Step i 4260 1041
# Step i 4270 1031
# Step i 4280 1021
# Step i 4300 1001
# Step i 4310 991
# Step i 4320 981
# Step i 4330 971
# Step i 4350 951
# Step i 4380 921
# Step i 4390 911
# Step i 4400 901
# Step i 4450 851
# Step i 4480 821
# Step i 4490 811
# Step i 4500 801
# Step i 4510 791
# Step i 4520 781
# Step i 4540 761
# Step i 4550 751
# Step i 4560 741
# Step i 4570 731
# Step i 4580 721
# Step i 4590 711
# Step i 4600 701
# Step i 4610 691
# Step i 4630 671
# Step i 4640 661
# Step i 4670 631
# Step i 4690 611
# Step i 4700 601
# Step i 4720 581
# Step i 4730 571
# Step i 4750 551
# Step i 4760 541
# Step i 4800 501
# Step i 4820 481
# Step i 4830 471
# Step i 4840 461
# Step i 4850 451
# Step i 4860 441
# Step i 4880 421
# Step i 4890 411
# Step i 4900 401
# Step i 4910 391
# Step i 4920 381
# Step i 4940 361
# Step i 4950 351
# Step i 4960 341
# Step i 4970 331
# Step i 4980 321
# Step i 5000 301
# Step i 5020 281
# Step i 5040 261
# Step i 5050 251
# Step i 5060 241
# Step i 5070 231
# Step i 5080 221
# Step i 5100 201
# Step i 5120 181
# Step i 5130 171
# Step i 5160 141
# Step i 5170 131
# Step i 5190 111
# Step i 5200 101
# Step i 5210 91
# Step i 5230 71
# Step i 5240 61
# Step i 5250 51
# Step i 5260 41
# Step i 5300 1
# Graph with 2588 nodes and 0 edges
# CPU times: total: 47min 33s
# Wall time: 47min 40s
# <timed exec>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.

# %%
model_with_graph = draw_graph_on_model(bin_reco_small, vessel_graph3)
ColorMapVisualizer(model_with_graph.astype(np.uint8)).visualize()

# %%
# vessel_graph = pickle.load(open("no_reco_now.pickle", "rb"))
pickle.dump(vessel_graph3, open('only_vertices_siimple_get_vessel.pickle', 'wb'))

# %%
# %%time
vessel_graph_rm = remove_graph_components(vessel_graph_cn6)
print(nx.info(vessel_graph_rm))
# Out:
# Graph with 2589 nodes and 2587 edges
# CPU times: total: 0 ns
# Wall time: 5.06 ms
# <timed exec>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.

# %%
model_with_graph = draw_graph_on_model(bin_reco_small, vessel_graph_rm)
ColorMapVisualizer(model_with_graph.astype(np.uint8)).visualize()

# %%
pickle.dump(vessel_graph_rm, open('removed-small.pickle', 'wb'))

# %%
# %%time
edt_img = distance_transform_edt(bin_reco_small)
# Out:
# CPU times: total: 3.17 s
# Wall time: 3.17 s

# %%
# %%time
vessel_graph_cn = connect_endings_3d(vessel_graph3, edt_img)
print(nx.info(vessel_graph_cn))
# Out:
# Endings:  2588
# Endings:  2587
# Endings:  2585
# Endings:  2583
# Endings:  2581
# Endings:  2580
# Endings:  2578
# Endings:  2576
# Endings:  2574
# Endings:  2572
# Endings:  2570
# Endings:  2568
# Endings:  2567
# Endings:  2566
# Endings:  2564
# Endings:  2562
# Endings:  2560
# Endings:  2558
# Endings:  2556
# Endings:  2555
# Endings:  2554
# Endings:  2552
# Endings:  2550
# Endings:  2548
# Endings:  2546
# Endings:  2544
# Endings:  2542
# Endings:  2541
# Endings:  2539
# Endings:  2538
# Endings:  2536
# Endings:  2534
# Endings:  2533
# Endings:  2532
# Endings:  2530
# Endings:  2528
# Endings:  2526
# Endings:  2525
# Endings:  2523
# Endings:  2522
# Endings:  2520
# Endings:  2518
# Endings:  2516
# Endings:  2515
# Endings:  2514
# Endings:  2513
# Endings:  2511
# Endings:  2510
# Endings:  2508
# Endings:  2507
# Endings:  2505
# Endings:  2504
# Endings:  2502
# Endings:  2501
# Endings:  2499
# Endings:  2497
# Endings:  2495
# Endings:  2494
# Endings:  2492
# Endings:  2490
# Endings:  2489
# Endings:  2488
# Endings:  2486
# Endings:  2484
# Endings:  2483
# Endings:  2482
# Endings:  2481
# Endings:  2479
# Endings:  2477
# Endings:  2475
# Endings:  2474
# Endings:  2472
# Endings:  2471
# Endings:  2469
# Endings:  2467
# Endings:  2465
# Endings:  2463
# Endings:  2461
# Endings:  2459
# Endings:  2458
# Endings:  2456
# Endings:  2455
# Endings:  2454
# Endings:  2453
# Endings:  2451
# Endings:  2449
# Endings:  2447
# Endings:  2446
# Endings:  2444
# Endings:  2442
# Endings:  2440
# Endings:  2439
# Endings:  2438
# Endings:  2437
# Endings:  2435
# Endings:  2433
# Endings:  2432
# Endings:  2431
# Endings:  2430
# Endings:  2428
# Endings:  2426
# Endings:  2424
# Endings:  2422
# Endings:  2421
# Endings:  2420
# Endings:  2418
# Endings:  2416
# Endings:  2415
# Endings:  2413
# Endings:  2412
# Endings:  2410
# Endings:  2408
# Endings:  2407
# Endings:  2405
# Endings:  2404
# Endings:  2402
# Endings:  2400
# Endings:  2398
# Endings:  2396
# Endings:  2394
# Endings:  2392
# Endings:  2390
# Endings:  2389
# Endings:  2387
# Endings:  2386
# Endings:  2384
# Endings:  2383
# Endings:  2381
# Endings:  2379
# Endings:  2377
# Endings:  2375
# Endings:  2374
# Endings:  2372
# Endings:  2371
# Endings:  2369
# Endings:  2368
# Endings:  2367
# Endings:  2365
# Endings:  2363
# Endings:  2362
# Endings:  2361
# Endings:  2360
# Endings:  2359
# Endings:  2357
# Endings:  2356
# Endings:  2355
# Endings:  2353
# Endings:  2352
# Endings:  2350
# Endings:  2348
# Endings:  2347
# Endings:  2346
# Endings:  2344
# Endings:  2342
# Endings:  2340
# Endings:  2338
# Endings:  2336
# Endings:  2334
# Endings:  2333
# Endings:  2331
# Endings:  2329
# Endings:  2328
# Endings:  2326
# Endings:  2324
# Endings:  2322
# Endings:  2321
# Endings:  2319
# Endings:  2318
# Endings:  2316
# Endings:  2314
# Endings:  2312
# Endings:  2310
# Endings:  2309
# Endings:  2307
# Endings:  2305
# Endings:  2304
# Endings:  2302
# Endings:  2301
# Endings:  2300
# Endings:  2298
# Endings:  2297
# Endings:  2295
# Endings:  2293
# Endings:  2292
# Endings:  2290
# Endings:  2288
# Endings:  2286
# Endings:  2284
# Endings:  2282
# Endings:  2280
# Endings:  2278
# Endings:  2276
# Endings:  2275
# Endings:  2274
# Endings:  2273
# Endings:  2271
# Endings:  2269
# Endings:  2267
# Endings:  2265
# Endings:  2263
# Endings:  2261
# Endings:  2259
# Endings:  2257
# Endings:  2255
# Endings:  2254
# Endings:  2253
# Endings:  2251
# Endings:  2249
# Endings:  2247
# Endings:  2245
# Endings:  2244
# Endings:  2242
# Endings:  2240
# Endings:  2239
# Endings:  2237
# Endings:  2236
# Endings:  2234
# Endings:  2233
# Endings:  2231
# Endings:  2229
# Endings:  2228
# Endings:  2227
# Endings:  2225
# Endings:  2223
# Endings:  2222
# Endings:  2220
# Endings:  2219
# Endings:  2217
# Endings:  2216
# Endings:  2215
# Endings:  2213
# Endings:  2211
# Endings:  2210
# Endings:  2209
# Endings:  2208
# Endings:  2207
# Endings:  2205
# Endings:  2204
# Endings:  2202
# Endings:  2201
# Endings:  2199
# Endings:  2197
# Endings:  2196
# Endings:  2194
# Endings:  2192
# Endings:  2190
# Endings:  2189
# Endings:  2187
# Endings:  2185
# Endings:  2184
# Endings:  2182
# Endings:  2180
# Endings:  2178
# Endings:  2177
# Endings:  2175
# Endings:  2174
# Endings:  2173
# Endings:  2171
# Endings:  2170
# Endings:  2169
# Endings:  2168
# Endings:  2167
# Endings:  2165
# Endings:  2163
# Endings:  2161
# Endings:  2160
# Endings:  2158
# Endings:  2157
# Endings:  2156
# Endings:  2154
# Endings:  2153
# Endings:  2152
# Endings:  2151
# Endings:  2149
# Endings:  2148
# Endings:  2146
# Endings:  2145
# Endings:  2143
# Endings:  2141
# Endings:  2140
# Endings:  2139
# Endings:  2137
# Endings:  2136
# Endings:  2134
# Endings:  2132
# Endings:  2130
# Endings:  2128
# Endings:  2127
# Endings:  2126
# Endings:  2124
# Endings:  2122
# Endings:  2121
# Endings:  2119
# Endings:  2118
# Endings:  2116
# Endings:  2115
# Endings:  2113
# Endings:  2112
# Endings:  2110
# Endings:  2109
# Endings:  2108
# Endings:  2106
# Endings:  2105
# Endings:  2103
# Endings:  2101
# Endings:  2100
# Endings:  2098
# Endings:  2097
# Endings:  2096
# Endings:  2094
# Endings:  2092
# Endings:  2090
# Endings:  2089
# Endings:  2087
# Endings:  2085
# Endings:  2084
# Endings:  2082
# Endings:  2081
# Endings:  2079
# Endings:  2077
# Endings:  2076
# Endings:  2074
# Endings:  2073
# Endings:  2072
# Endings:  2070
# Endings:  2068
# Endings:  2066
# Endings:  2065
# Endings:  2063
# Endings:  2061
# Endings:  2060
# Endings:  2058
# Endings:  2057
# Endings:  2055
# Endings:  2054
# Endings:  2053
# Endings:  2052
# Endings:  2050
# Endings:  2048
# Endings:  2046
# Endings:  2045
# Endings:  2043
# Endings:  2041
# Endings:  2040
# Endings:  2038
# Endings:  2036
# Endings:  2034
# Endings:  2032
# Endings:  2030
# Endings:  2029
# Endings:  2027
# Endings:  2026
# Endings:  2024
# Endings:  2022
# Endings:  2021
# Endings:  2020
# Endings:  2018
# Endings:  2016
# Endings:  2014
# Endings:  2013
# Endings:  2011
# Endings:  2009
# Endings:  2008
# Endings:  2006
# Endings:  2004
# Endings:  2002
# Endings:  2001
# Endings:  2000
# Endings:  1998
# Endings:  1997
# Endings:  1995
# Endings:  1993
# Endings:  1991
# Endings:  1989
# Endings:  1987
# Endings:  1985
# Endings:  1984
# Endings:  1982
# Endings:  1980
# Endings:  1979
# Endings:  1977
# Endings:  1975
# Endings:  1974
# Endings:  1972
# Endings:  1970
# Endings:  1968
# Endings:  1966
# Endings:  1965
# Endings:  1963
# Endings:  1961
# Endings:  1960
# Endings:  1959
# Endings:  1957
# Endings:  1955
# Endings:  1954
# Endings:  1953
# Endings:  1951
# Endings:  1950
# Endings:  1949
# Endings:  1948
# Endings:  1947
# Endings:  1946
# Endings:  1945
# Endings:  1943
# Endings:  1942
# Endings:  1940
# Endings:  1939
# Endings:  1937
# Endings:  1935
# Endings:  1934
# Endings:  1932
# Endings:  1930
# Endings:  1929
# Endings:  1927
# Endings:  1926
# Endings:  1925
# Endings:  1923
# Endings:  1921
# Endings:  1920
# Endings:  1918
# Endings:  1917
# Endings:  1915
# Endings:  1913
# Endings:  1912
# Endings:  1911
# Endings:  1910
# Endings:  1908
# Endings:  1906
# Endings:  1905
# Endings:  1904
# Endings:  1902
# Endings:  1901
# Endings:  1900
# Endings:  1898
# Endings:  1897
# Endings:  1895
# Endings:  1893
# Endings:  1891
# Endings:  1889
# Endings:  1887
# Endings:  1885
# Endings:  1883
# Endings:  1882
# Endings:  1880
# Endings:  1878
# Endings:  1876
# Endings:  1875
# Endings:  1874
# Endings:  1872
# Endings:  1871
# Endings:  1870
# Endings:  1868
# Endings:  1866
# Endings:  1864
# Endings:  1862
# Endings:  1860
# Endings:  1858
# Endings:  1856
# Endings:  1855
# Endings:  1853
# Endings:  1851
# Endings:  1849
# Endings:  1848
# Endings:  1846
# Endings:  1844
# Endings:  1842
# Endings:  1840
# Endings:  1838
# Endings:  1837
# Endings:  1835
# Endings:  1833
# Endings:  1831
# Endings:  1830
# Endings:  1828
# Endings:  1827
# Endings:  1826
# Endings:  1824
# Endings:  1822
# Endings:  1820
# Endings:  1819
# Endings:  1818
# Endings:  1816
# Endings:  1814
# Endings:  1812
# Endings:  1810
# Endings:  1808
# Endings:  1806
# Endings:  1805
# Endings:  1804
# Endings:  1803
# Endings:  1801
# Endings:  1799
# Endings:  1797
# Endings:  1796
# Endings:  1794
# Endings:  1792
# Endings:  1790
# Endings:  1788
# Endings:  1786
# Endings:  1785
# Endings:  1783
# Endings:  1781
# Endings:  1780
# Endings:  1779
# Endings:  1777
# Endings:  1776
# Endings:  1774
# Endings:  1772
# Endings:  1770
# Endings:  1768
# Endings:  1767
# Endings:  1766
# Endings:  1764
# Endings:  1763
# Endings:  1762
# Endings:  1760
# Endings:  1758
# Endings:  1757
# Endings:  1755
# Endings:  1754
# Endings:  1752
# Endings:  1751
# Endings:  1749
# Endings:  1747
# Endings:  1745
# Endings:  1743
# Endings:  1741
# Endings:  1739
# Endings:  1737
# Endings:  1736
# Endings:  1734
# Endings:  1732
# Endings:  1731
# Endings:  1729
# Endings:  1727
# Endings:  1726
# Endings:  1725
# Endings:  1724
# Endings:  1722
# Endings:  1720
# Endings:  1719
# Endings:  1717
# Endings:  1716
# Endings:  1715
# Endings:  1714
# Endings:  1712
# Endings:  1710
# Endings:  1708
# Endings:  1706
# Endings:  1705
# Endings:  1703
# Endings:  1701
# Endings:  1699
# Endings:  1697
# Endings:  1695
# Endings:  1694
# Endings:  1692
# Endings:  1691
# Endings:  1689
# Endings:  1688
# Endings:  1686
# Endings:  1684
# Endings:  1683
# Endings:  1682
# Endings:  1680
# Endings:  1678
# Endings:  1676
# Endings:  1674
# Endings:  1673
# Endings:  1671
# Endings:  1670
# Endings:  1668
# Endings:  1666
# Endings:  1664
# Endings:  1662
# Endings:  1660
# Endings:  1659
# Endings:  1658
# Endings:  1656
# Endings:  1655
# Endings:  1653
# Endings:  1651
# Endings:  1650
# Endings:  1649
# Endings:  1647
# Endings:  1645
# Endings:  1644
# Endings:  1642
# Endings:  1641
# Endings:  1640
# Endings:  1639
# Endings:  1637
# Endings:  1635
# Endings:  1633
# Endings:  1631
# Endings:  1630
# Endings:  1628
# Endings:  1626
# Endings:  1624
# Endings:  1623
# Endings:  1621
# Endings:  1620
# Endings:  1619
# Endings:  1617
# Endings:  1615
# Endings:  1613
# Endings:  1612
# Endings:  1610
# Endings:  1608
# Endings:  1606
# Endings:  1605
# Endings:  1603
# Endings:  1602
# Endings:  1600
# Endings:  1598
# Endings:  1597
# Endings:  1596
# Endings:  1594
# Endings:  1593
# Endings:  1591
# Endings:  1590
# Endings:  1589
# Endings:  1587
# Endings:  1586
# Endings:  1584
# Endings:  1582
# Endings:  1580
# Endings:  1578
# Endings:  1577
# Endings:  1575
# Endings:  1573
# Endings:  1571
# Endings:  1569
# Endings:  1568
# Endings:  1567
# Endings:  1565
# Endings:  1564
# Endings:  1563
# Endings:  1562
# Endings:  1561
# Endings:  1559
# Endings:  1558
# Endings:  1556
# Endings:  1555
# Endings:  1553
# Endings:  1551
# Endings:  1550
# Endings:  1548
# Endings:  1546
# Endings:  1545
# Endings:  1544
# Endings:  1542
# Endings:  1540
# Endings:  1538
# Endings:  1537
# Endings:  1536
# Endings:  1534
# Endings:  1532
# Endings:  1531
# Endings:  1529
# Endings:  1527
# Endings:  1525
# Endings:  1524
# Endings:  1523
# Endings:  1521
# Endings:  1519
# Endings:  1517
# Endings:  1515
# Endings:  1513
# Endings:  1511
# Endings:  1510
# Endings:  1508
# Endings:  1506
# Endings:  1505
# Endings:  1503
# Endings:  1501
# Endings:  1499
# Endings:  1498
# Endings:  1496
# Endings:  1494
# Endings:  1492
# Endings:  1490
# Endings:  1489
# Endings:  1487
# Endings:  1486
# Endings:  1485
# Endings:  1483
# Endings:  1481
# Endings:  1479
# Endings:  1477
# Endings:  1476
# Endings:  1474
# Endings:  1472
# Endings:  1470
# Endings:  1469
# Endings:  1467
# Endings:  1465
# Endings:  1463
# Endings:  1461
# Endings:  1459
# Endings:  1457
# Endings:  1455
# Endings:  1453
# Endings:  1451
# Endings:  1449
# Endings:  1447
# Endings:  1446
# Endings:  1445
# Endings:  1444
# Endings:  1443
# Endings:  1442
# Endings:  1440
# Endings:  1439
# Endings:  1438
# Endings:  1437
# Endings:  1435
# Endings:  1433
# Endings:  1431
# Endings:  1429
# Endings:  1428
# Endings:  1426
# Endings:  1425
# Endings:  1423
# Endings:  1421
# Endings:  1420
# Endings:  1418
# Endings:  1417
# Endings:  1416
# Endings:  1415
# Endings:  1413
# Endings:  1412
# Endings:  1410
# Endings:  1409
# Endings:  1407
# Endings:  1406
# Endings:  1404
# Endings:  1402
# Endings:  1400
# Endings:  1398
# Endings:  1396
# Endings:  1394
# Endings:  1392
# Endings:  1390
# Endings:  1389
# Endings:  1388
# Endings:  1386
# Endings:  1385
# Endings:  1383
# Endings:  1382
# Endings:  1381
# Endings:  1379
# Endings:  1378
# Endings:  1376
# Endings:  1374
# Endings:  1372
# Endings:  1371
# Endings:  1369
# Endings:  1367
# Endings:  1366
# Endings:  1365
# Endings:  1363
# Endings:  1361
# Endings:  1360
# Endings:  1358
# Endings:  1356
# Endings:  1354
# Endings:  1352
# Endings:  1351
# Endings:  1349
# Endings:  1347
# Endings:  1345
# Endings:  1343
# Endings:  1341
# Endings:  1340
# Endings:  1338
# Endings:  1337
# Endings:  1336
# Endings:  1334
# Endings:  1333
# Endings:  1332
# Endings:  1330
# Endings:  1328
# Endings:  1327
# Endings:  1325
# Endings:  1324
# Endings:  1322
# Endings:  1321
# Endings:  1320
# Endings:  1319
# Endings:  1317
# Endings:  1315
# Endings:  1313
# Endings:  1311
# Endings:  1310
# Endings:  1308
# Endings:  1306
# Endings:  1305
# Endings:  1304
# Endings:  1302
# Endings:  1300
# Endings:  1298
# Endings:  1296
# Endings:  1294
# Endings:  1293
# Endings:  1291
# Endings:  1290
# Endings:  1288
# Endings:  1287
# Endings:  1285
# Endings:  1284
# Endings:  1282
# Endings:  1280
# Endings:  1279
# Endings:  1278
# Endings:  1277
# Endings:  1275
# Endings:  1274
# Endings:  1272
# Endings:  1271
# Endings:  1269
# Endings:  1267
# Endings:  1266
# Endings:  1264
# Endings:  1263
# Endings:  1261
# Endings:  1259
# Endings:  1258
# Endings:  1257
# Endings:  1255
# Endings:  1253
# Endings:  1252
# Endings:  1250
# Endings:  1249
# Endings:  1247
# Endings:  1246
# Endings:  1245
# Endings:  1243
# Endings:  1241
# Endings:  1239
# Endings:  1238
# Endings:  1237
# Endings:  1236
# Endings:  1234
# Endings:  1232
# Endings:  1231
# Endings:  1229
# Endings:  1227
# Endings:  1226
# Endings:  1225
# Endings:  1223
# Endings:  1221
# Endings:  1220
# Endings:  1219
# Endings:  1217
# Endings:  1215
# Endings:  1213
# Endings:  1212
# Endings:  1210
# Endings:  1209
# Endings:  1207
# Endings:  1206
# Endings:  1205
# Endings:  1203
# Endings:  1201
# Endings:  1199
# Endings:  1197
# Endings:  1195
# Endings:  1193
# Endings:  1191
# Endings:  1189
# Endings:  1188
# Endings:  1187
# Endings:  1186
# Endings:  1185
# Endings:  1183
# Endings:  1181
# Endings:  1180
# Endings:  1179
# Endings:  1178
# Endings:  1176
# Endings:  1174
# Endings:  1172
# Endings:  1170
# Endings:  1168
# Endings:  1167
# Endings:  1165
# Endings:  1164
# Endings:  1163
# Endings:  1162
# Endings:  1160
# Endings:  1159
# Endings:  1158
# Endings:  1156
# Endings:  1154
# Endings:  1153
# Endings:  1151
# Endings:  1150
# Endings:  1148
# Endings:  1147
# Endings:  1146
# Endings:  1145
# Endings:  1144
# Endings:  1143
# Endings:  1142
# Endings:  1140
# Endings:  1138
# Endings:  1136
# Endings:  1135
# Endings:  1134
# Endings:  1132
# Endings:  1131
# Endings:  1129
# Endings:  1128
# Endings:  1127
# Endings:  1126
# Endings:  1124
# Endings:  1123
# Endings:  1122
# Endings:  1121
# Endings:  1119
# Endings:  1117
# Endings:  1116
# Endings:  1114
# Endings:  1113
# Endings:  1112
# Endings:  1110
# Endings:  1108
# Endings:  1106
# Endings:  1105
# Endings:  1104
# Endings:  1103
# Endings:  1101
# Endings:  1099
# Endings:  1098
# Endings:  1097
# Endings:  1096
# Endings:  1094
# Endings:  1092
# Endings:  1090
# Endings:  1088
# Endings:  1087
# Endings:  1086
# Endings:  1084
# Endings:  1083
# Endings:  1081
# Endings:  1079
# Endings:  1078
# Endings:  1077
# Endings:  1076
# Endings:  1075
# Endings:  1073
# Endings:  1071
# Endings:  1069
# Endings:  1067
# Endings:  1066
# Endings:  1065
# Endings:  1063
# Endings:  1061
# Endings:  1060
# Endings:  1059
# Endings:  1058
# Endings:  1056
# Endings:  1054
# Endings:  1052
# Endings:  1051
# Endings:  1049
# Endings:  1047
# Endings:  1045
# Endings:  1044
# Endings:  1042
# Endings:  1041
# Endings:  1040
# Endings:  1038
# Endings:  1036
# Endings:  1034
# Endings:  1033
# Endings:  1031
# Endings:  1029
# Endings:  1027
# Endings:  1026
# Endings:  1024
# Endings:  1022
# Endings:  1020
# Endings:  1019
# Endings:  1017
# Endings:  1015
# Endings:  1013
# Endings:  1011
# Endings:  1010
# Endings:  1008
# Endings:  1007
# Endings:  1006
# Endings:  1005
# Endings:  1004
# Endings:  1002
# Endings:  1001
# Endings:  999
# Endings:  997
# Endings:  995
# Endings:  994
# Endings:  993
# Endings:  992
# Endings:  990
# Endings:  988
# Endings:  987
# Endings:  986
# Endings:  984
# Endings:  982
# Endings:  980
# Endings:  979
# Endings:  977
# Endings:  976
# Endings:  974
# Endings:  972
# Endings:  971
# Endings:  969
# Endings:  968
# Endings:  967
# Endings:  965
# Endings:  963
# Endings:  962
# Endings:  960
# Endings:  959
# Endings:  958
# Endings:  957
# Endings:  956
# Endings:  954
# Endings:  952
# Endings:  950
# Endings:  949
# Endings:  948
# Endings:  947
# Endings:  945
# Endings:  943
# Endings:  941
# Endings:  940
# Endings:  939
# Endings:  938
# Endings:  937
# Endings:  936
# Endings:  935
# Endings:  933
# Endings:  931
# Endings:  930
# Endings:  928
# Endings:  927
# Endings:  925
# Endings:  923
# Endings:  921
# Endings:  919
# Endings:  918
# Endings:  916
# Endings:  915
# Endings:  913
# Endings:  912
# Endings:  911
# Endings:  909
# Endings:  907
# Endings:  906
# Endings:  904
# Endings:  902
# Endings:  901
# Endings:  899
# Endings:  898
# Endings:  896
# Endings:  895
# Endings:  893
# Endings:  891
# Endings:  890
# Endings:  888
# Endings:  887
# Endings:  885
# Endings:  884
# Endings:  883
# Endings:  882
# Endings:  881
# Endings:  879
# Endings:  878
# Endings:  876
# Endings:  875
# Endings:  873
# Endings:  871
# Endings:  869
# Endings:  867
# Endings:  866
# Endings:  864
# Endings:  862
# Endings:  860
# Endings:  858
# Endings:  856
# Endings:  855
# Endings:  853
# Endings:  851
# Endings:  849
# Endings:  848
# Endings:  847
# Endings:  846
# Endings:  844
# Endings:  842
# Endings:  841
# Endings:  840
# Endings:  838
# Endings:  836
# Endings:  834
# Endings:  833
# Endings:  831
# Endings:  829
# Endings:  828
# Endings:  826
# Endings:  825
# Endings:  823
# Endings:  821
# Endings:  819
# Endings:  818
# Endings:  816
# Endings:  814
# Endings:  813
# Endings:  811
# Endings:  809
# Endings:  807
# Endings:  805
# Endings:  804
# Endings:  802
# Endings:  800
# Endings:  799
# Endings:  797
# Endings:  795
# Endings:  794
# Endings:  792
# Endings:  790
# Endings:  789
# Endings:  787
# Endings:  785
# Endings:  784
# Endings:  783
# Endings:  781
# Endings:  779
# Endings:  777
# Endings:  776
# Endings:  774
# Endings:  772
# Endings:  771
# Endings:  770
# Endings:  769
# Endings:  767
# Endings:  766
# Endings:  764
# Endings:  762
# Endings:  760
# Endings:  759
# Endings:  758
# Endings:  757
# Endings:  755
# Endings:  753
# Endings:  752
# Endings:  750
# Endings:  749
# Endings:  747
# Endings:  746
# Endings:  744
# Endings:  743
# Endings:  742
# Endings:  740
# Endings:  739
# Endings:  738
# Endings:  736
# Endings:  734
# Endings:  733
# Endings:  731
# Endings:  729
# Endings:  728
# Endings:  727
# Endings:  726
# Endings:  725
# Endings:  723
# Endings:  721
# Endings:  720
# Endings:  718
# Endings:  716
# Endings:  714
# Endings:  712
# Endings:  711
# Endings:  710
# Endings:  709
# Endings:  708
# Endings:  706
# Endings:  704
# Endings:  703
# Endings:  702
# Endings:  700
# Endings:  698
# Endings:  696
# Endings:  695
# Endings:  693
# Endings:  691
# Endings:  690
# Endings:  688
# Endings:  686
# Endings:  684
# Endings:  682
# Endings:  680
# Endings:  679
# Endings:  677
# Endings:  675
# Endings:  674
# Endings:  672
# Endings:  671
# Endings:  670
# Endings:  668
# Endings:  667
# Endings:  665
# Endings:  663
# Endings:  661
# Endings:  659
# Endings:  658
# Endings:  656
# Endings:  654
# Endings:  652
# Endings:  651
# Endings:  650
# Endings:  648
# Endings:  646
# Endings:  645
# Endings:  644
# Endings:  642
# Endings:  641
# Endings:  639
# Endings:  637
# Endings:  636
# Endings:  634
# Endings:  633
# Endings:  631
# Endings:  629
# Endings:  627
# Endings:  625
# Endings:  623
# Endings:  621
# Endings:  619
# Endings:  617
# Endings:  615
# Endings:  614
# Endings:  612
# Endings:  610
# Endings:  608
# Endings:  606
# Endings:  604
# Endings:  602
# Endings:  601
# Endings:  599
# Endings:  598
# Endings:  597
# Endings:  595
# Endings:  593
# Endings:  592
# Endings:  590
# Endings:  588
# Endings:  586
# Endings:  584
# Endings:  583
# Endings:  582
# Endings:  581
# Endings:  579
# Endings:  577
# Endings:  575
# Endings:  573
# Endings:  571
# Endings:  569
# Endings:  567
# Endings:  566
# Endings:  565
# Endings:  563
# Endings:  562
# Endings:  561
# Endings:  559
# Endings:  558
# Endings:  556
# Endings:  554
# Endings:  553
# Endings:  552
# Endings:  551
# Endings:  550
# Endings:  549
# Endings:  547
# Endings:  545
# Endings:  543
# Endings:  542
# Endings:  540
# Endings:  538
# Endings:  537
# Endings:  536
# Endings:  534
# Endings:  532
# Endings:  531
# Endings:  530
# Endings:  529
# Endings:  527
# Endings:  525
# Endings:  524
# Endings:  522
# Endings:  521
# Endings:  520
# Endings:  518
# Endings:  516
# Endings:  515
# Endings:  514
# Endings:  512
# Endings:  511
# Endings:  509
# Endings:  508
# Endings:  507
# Endings:  506
# Endings:  505
# Endings:  504
# Endings:  502
# Endings:  500
# Endings:  498
# Endings:  496
# Endings:  495
# Endings:  493
# Endings:  492
# Endings:  491
# Endings:  490
# Endings:  488
# Endings:  486
# Endings:  484
# Endings:  482
# Endings:  480
# Endings:  478
# Endings:  476
# Endings:  475
# Endings:  473
# Endings:  472
# Endings:  470
# Endings:  468
# Endings:  466
# Endings:  464
# Endings:  462
# Endings:  460
# Endings:  458
# Endings:  456
# Endings:  455
# Endings:  454
# Endings:  452
# Endings:  450
# Endings:  448
# Endings:  446
# Endings:  445
# Endings:  444
# Endings:  442
# Endings:  440
# Endings:  438
# Endings:  437
# Endings:  435
# Endings:  433
# Endings:  431
# Endings:  430
# Endings:  429
# Endings:  428
# Endings:  427
# Endings:  426
# Endings:  424
# Endings:  422
# Endings:  421
# Endings:  420
# Endings:  418
# Endings:  416
# Endings:  414
# Endings:  412
# Endings:  411
# Endings:  410
# Endings:  408
# Endings:  406
# Endings:  404
# Endings:  402
# Endings:  401
# Endings:  399
# Endings:  397
# Endings:  395
# Endings:  393
# Endings:  391
# Endings:  389
# Endings:  388
# Endings:  386
# Endings:  384
# Endings:  382
# Endings:  381
# Endings:  380
# Endings:  378
# Endings:  376
# Endings:  375
# Endings:  373
# Endings:  371
# Endings:  369
# Endings:  368
# Endings:  366
# Endings:  364
# Endings:  362
# Endings:  360
# Endings:  359
# Endings:  358
# Endings:  357
# Endings:  356
# Endings:  355
# Endings:  353
# Endings:  351
# Endings:  350
# Endings:  349
# Endings:  348
# Endings:  347
# Endings:  346
# Endings:  345
# Endings:  343
# Endings:  341
# Endings:  339
# Endings:  338
# Endings:  337
# Endings:  336
# Endings:  334
# Endings:  333
# Endings:  331
# Endings:  329
# Endings:  327
# Endings:  325
# Endings:  323
# Endings:  321
# Endings:  319
# Endings:  317
# Endings:  316
# Endings:  315
# Endings:  313
# Endings:  312
# Endings:  311
# Endings:  310
# Endings:  308
# Endings:  307
# Endings:  306
# Endings:  304
# Endings:  303
# Endings:  301
# Endings:  299
# Endings:  298
# Endings:  296
# Endings:  294
# Endings:  293
# Endings:  291
# Endings:  289
# Endings:  288
# Endings:  286
# Endings:  284
# Endings:  282
# Endings:  281
# Endings:  279
# Endings:  277
# Endings:  275
# Endings:  274
# Endings:  272
# Endings:  271
# Endings:  270
# Endings:  268
# Endings:  266
# Endings:  264
# Endings:  262
# Endings:  261
# Endings:  259
# Endings:  257
# Endings:  256
# Endings:  255
# Endings:  253
# Endings:  252
# Endings:  250
# Endings:  249
# Endings:  248
# Endings:  246
# Endings:  244
# Endings:  242
# Endings:  241
# Endings:  239
# Endings:  238
# Endings:  236
# Endings:  235
# Endings:  233
# Endings:  231
# Endings:  229
# Endings:  227
# Endings:  225
# Endings:  224
# Endings:  222
# Endings:  220
# Endings:  218
# Endings:  217
# Endings:  215
# Endings:  213
# Endings:  211
# Endings:  209
# Endings:  207
# Endings:  205
# Endings:  204
# Endings:  202
# Endings:  200
# Endings:  198
# Endings:  197
# Endings:  196
# Endings:  194
# Endings:  193
# Endings:  192
# Endings:  190
# Endings:  189
# Endings:  187
# Endings:  185
# Endings:  183
# Endings:  181
# Endings:  180
# Endings:  179
# Endings:  178
# Endings:  176
# Endings:  174
# Endings:  173
# Endings:  172
# Endings:  170
# Endings:  169
# Endings:  168
# Endings:  167
# Endings:  166
# Endings:  165
# Endings:  164
# Endings:  163
# Endings:  162
# Endings:  160
# Endings:  159
# Endings:  157
# Endings:  156
# Endings:  155
# Endings:  154
# Endings:  153
# Endings:  151
# Endings:  150
# Endings:  148
# Endings:  146
# Endings:  144
# Endings:  143
# Endings:  141
# Endings:  139
# Endings:  138
# Endings:  136
# Endings:  135
# Endings:  133
# Endings:  132
# Endings:  131
# Endings:  129
# Endings:  128
# Endings:  127
# Endings:  126
# Endings:  125
# Endings:  124
# Endings:  123
# Endings:  121
# Endings:  120
# Endings:  119
# Endings:  118
# Endings:  116
# Endings:  114
# Endings:  113
# Endings:  112
# Endings:  111
# Endings:  109
# Endings:  108
# Endings:  106
# Endings:  104
# Endings:  103
# Endings:  101
# Endings:  99
# Endings:  98
# Endings:  97
# Endings:  96
# Endings:  94
# Endings:  93
# Endings:  91
# Endings:  89
# Endings:  87
# Endings:  86
# Endings:  84
# Endings:  82
# Endings:  81
# Endings:  79
# Endings:  78
# Endings:  77
# Endings:  75
# Endings:  73
# Endings:  72
# Endings:  71
# Endings:  70
# Endings:  68
# Endings:  66
# Endings:  65
# Endings:  64
# Endings:  62
# Endings:  60
# Endings:  59
# Endings:  58
# Endings:  57
# Endings:  55
# Endings:  54
# Endings:  53
# Endings:  51
# Endings:  49
# Endings:  48
# Endings:  47
# Endings:  45
# Endings:  43
# Endings:  42
# Endings:  41
# Endings:  40
# Endings:  38
# Endings:  37
# Endings:  36
# Endings:  35
# Endings:  33
# Endings:  31
# Endings:  30
# Endings:  28
# Endings:  27
# Endings:  25
# Endings:  23
# Endings:  21
# Endings:  20
# Endings:  18
# Endings:  17
# Endings:  16
# Endings:  14
# Endings:  13
# Endings:  11
# Endings:  10
# Endings:  8
# Endings:  7
# Endings:  6
# Endings:  5
# Endings:  4
# Endings:  2
# Endings:  1
# Endings:  0
# Graph with 2589 nodes and 1578 edges
# CPU times: total: 2min 16s
# Wall time: 2min 16s
# <timed exec>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.

# %%
vessel_graph_cn4 = connect_endings_3d(vessel_graph_cn3, edt_img, 4.)
print(nx.info(vessel_graph_cn4))
# Out:
# Endings:  531
# Endings:  530
# Endings:  529
# Endings:  528
# Endings:  527
# Endings:  526
# Endings:  525
# Endings:  524
# Endings:  523
# Endings:  522
# Endings:  521
# Endings:  519
# Endings:  518
# Endings:  517
# Endings:  516
# Endings:  515
# Endings:  514
# Endings:  513
# Endings:  512
# Endings:  511
# Endings:  510
# Endings:  509
# Endings:  508
# Endings:  507
# Endings:  506
# Endings:  505
# Endings:  504
# Endings:  503
# Endings:  502
# Endings:  501
# Endings:  500
# Endings:  499
# Endings:  498
# Endings:  497
# Endings:  496
# Endings:  495
# Endings:  494
# Endings:  493
# Endings:  492
# Endings:  491
# Endings:  490
# Endings:  489
# Endings:  488
# Endings:  487
# Endings:  486
# Endings:  485
# Endings:  484
# Endings:  483
# Endings:  482
# Endings:  481
# Endings:  480
# Endings:  479
# Endings:  478
# Endings:  477
# Endings:  476
# Endings:  475
# Endings:  474
# Endings:  473
# Endings:  472
# Endings:  471
# Endings:  470
# Endings:  469
# Endings:  468
# Endings:  466
# Endings:  465
# Endings:  464
# Endings:  463
# Endings:  462
# Endings:  461
# Endings:  460
# Endings:  459
# Endings:  458
# Endings:  457
# Endings:  456
# Endings:  455
# Endings:  454
# Endings:  453
# Endings:  452
# Endings:  451
# Endings:  450
# Endings:  449
# Endings:  448
# Endings:  447
# Endings:  446
# Endings:  445
# Endings:  444
# Endings:  443
# Endings:  442
# Endings:  441
# Endings:  440
# Endings:  439
# Endings:  438
# Endings:  437
# Endings:  436
# Endings:  435
# Endings:  434
# Endings:  433
# Endings:  432
# Endings:  431
# Endings:  430
# Endings:  429
# Endings:  427
# Endings:  426
# Endings:  424
# Endings:  423
# Endings:  422
# Endings:  421
# Endings:  420
# Endings:  419
# Endings:  418
# Endings:  417
# Endings:  416
# Endings:  415
# Endings:  414
# Endings:  413
# Endings:  412
# Endings:  411
# Endings:  410
# Endings:  409
# Endings:  408
# Endings:  407
# Endings:  406
# Endings:  405
# Endings:  404
# Endings:  403
# Endings:  402
# Endings:  401
# Endings:  400
# Endings:  399
# Endings:  398
# Endings:  397
# Endings:  396
# Endings:  395
# Endings:  394
# Endings:  393
# Endings:  392
# Endings:  391
# Endings:  390
# Endings:  389
# Endings:  388
# Endings:  387
# Endings:  386
# Endings:  384
# Endings:  382
# Endings:  381
# Endings:  380
# Endings:  379
# Endings:  378
# Endings:  377
# Endings:  376
# Endings:  375
# Endings:  374
# Endings:  373
# Endings:  372
# Endings:  371
# Endings:  370
# Endings:  369
# Endings:  368
# Endings:  367
# Endings:  366
# Endings:  365
# Endings:  364
# Endings:  363
# Endings:  362
# Endings:  361
# Endings:  360
# Endings:  359
# Endings:  357
# Endings:  356
# Endings:  355
# Endings:  354
# Endings:  353
# Endings:  352
# Endings:  351
# Endings:  350
# Endings:  349
# Endings:  348
# Endings:  347
# Endings:  346
# Endings:  345
# Endings:  344
# Endings:  343
# Endings:  342
# Endings:  341
# Endings:  340
# Endings:  339
# Endings:  338
# Endings:  337
# Endings:  336
# Endings:  335
# Endings:  334
# Endings:  333
# Endings:  332
# Endings:  331
# Endings:  329
# Endings:  328
# Endings:  327
# Endings:  326
# Endings:  325
# Endings:  324
# Endings:  323
# Endings:  322
# Endings:  321
# Endings:  320
# Endings:  319
# Endings:  318
# Endings:  317
# Endings:  316
# Endings:  315
# Endings:  314
# Endings:  313
# Endings:  312
# Endings:  311
# Endings:  310
# Endings:  309
# Endings:  308
# Endings:  307
# Endings:  306
# Endings:  305
# Endings:  304
# Endings:  303
# Endings:  302
# Endings:  301
# Endings:  300
# Endings:  299
# Endings:  298
# Endings:  297
# Endings:  296
# Endings:  295
# Endings:  294
# Endings:  293
# Endings:  292
# Endings:  291
# Endings:  290
# Endings:  289
# Endings:  288
# Endings:  287
# Endings:  286
# Endings:  285
# Endings:  284
# Endings:  283
# Endings:  282
# Endings:  281
# Endings:  280
# Endings:  279
# Endings:  278
# Endings:  277
# Endings:  276
# Endings:  275
# Endings:  274
# Endings:  273
# Endings:  272
# Endings:  271
# Endings:  270
# Endings:  269
# Endings:  268
# Endings:  267
# Endings:  266
# Endings:  265
# Endings:  264
# Endings:  263
# Endings:  262
# Endings:  261
# Endings:  260
# Endings:  259
# Endings:  258
# Endings:  257
# Endings:  256
# Endings:  255
# Endings:  254
# Endings:  253
# Endings:  252
# Endings:  251
# Endings:  250
# Endings:  249
# Endings:  248
# Endings:  247
# Endings:  246
# Endings:  245
# Endings:  244
# Endings:  243
# Endings:  242
# Endings:  241
# Endings:  240
# Endings:  239
# Endings:  238
# Endings:  237
# Endings:  236
# Endings:  235
# Endings:  234
# Endings:  233
# Endings:  232
# Endings:  231
# Endings:  230
# Endings:  229
# Endings:  228
# Endings:  227
# Endings:  226
# Endings:  225
# Endings:  224
# Endings:  223
# Endings:  222
# Endings:  221
# Endings:  220
# Endings:  219
# Endings:  218
# Endings:  217
# Endings:  216
# Endings:  215
# Endings:  214
# Endings:  213
# Endings:  212
# Endings:  211
# Endings:  210
# Endings:  209
# Endings:  207
# Endings:  206
# Endings:  205
# Endings:  204
# Endings:  203
# Endings:  202
# Endings:  201
# Endings:  200
# Endings:  199
# Endings:  198
# Endings:  197
# Endings:  196
# Endings:  195
# Endings:  194
# Endings:  193
# Endings:  192
# Endings:  191
# Endings:  190
# Endings:  189
# Endings:  188
# Endings:  187
# Endings:  186
# Endings:  185
# Endings:  184
# Endings:  183
# Endings:  182
# Endings:  181
# Endings:  180
# Endings:  179
# Endings:  178
# Endings:  177
# Endings:  176
# Endings:  175
# Endings:  174
# Endings:  173
# Endings:  172
# Endings:  171
# Endings:  170
# Endings:  169
# Endings:  168
# Endings:  167
# Endings:  166
# Endings:  165
# Endings:  164
# Endings:  163
# Endings:  162
# Endings:  161
# Endings:  160
# Endings:  159
# Endings:  158
# Endings:  157
# Endings:  156
# Endings:  155
# Endings:  154
# Endings:  153
# Endings:  152
# Endings:  151
# Endings:  150
# Endings:  149
# Endings:  148
# Endings:  147
# Endings:  146
# Endings:  145
# Endings:  144
# Endings:  143
# Endings:  142
# Endings:  141
# Endings:  140
# Endings:  139
# Endings:  137
# Endings:  136
# Endings:  135
# Endings:  134
# Endings:  133
# Endings:  132
# Endings:  131
# Endings:  130
# Endings:  129
# Endings:  128
# Endings:  127
# Endings:  126
# Endings:  125
# Endings:  124
# Endings:  123
# Endings:  122
# Endings:  121
# Endings:  120
# Endings:  119
# Endings:  118
# Endings:  117
# Endings:  116
# Endings:  115
# Endings:  114
# Endings:  113
# Endings:  112
# Endings:  111
# Endings:  110
# Endings:  109
# Endings:  108
# Endings:  107
# Endings:  106
# Endings:  105
# Endings:  104
# Endings:  103
# Endings:  102
# Endings:  101
# Endings:  100
# Endings:  99
# Endings:  98
# Endings:  97
# Endings:  96
# Endings:  95
# Endings:  94
# Endings:  93
# Endings:  92
# Endings:  91
# Endings:  90
# Endings:  89
# Endings:  88
# Endings:  87
# Endings:  86
# Endings:  85
# Endings:  84
# Endings:  83
# Endings:  82
# Endings:  81
# Endings:  80
# Endings:  79
# Endings:  78
# Endings:  77
# Endings:  76
# Endings:  75
# Endings:  74
# Endings:  73
# Endings:  72
# Endings:  71
# Endings:  70
# Endings:  69
# Endings:  68
# Endings:  67
# Endings:  66
# Endings:  65
# Endings:  64
# Endings:  63
# Endings:  62
# Endings:  61
# Endings:  60
# Endings:  59
# Endings:  58
# Endings:  57
# Endings:  56
# Endings:  55
# Endings:  54
# Endings:  53
# Endings:  52
# Endings:  51
# Endings:  50
# Endings:  49
# Endings:  48
# Endings:  47
# Endings:  46
# Endings:  45
# Endings:  43
# Endings:  42
# Endings:  40
# Endings:  39
# Endings:  38
# Endings:  37
# Endings:  36
# Endings:  35
# Endings:  34
# Endings:  33
# Endings:  32
# Endings:  31
# Endings:  30
# Endings:  29
# Endings:  28
# Endings:  27
# Endings:  26
# Endings:  25
# Endings:  24
# Endings:  23
# Endings:  22
# Endings:  21
# Endings:  20
# Endings:  19
# Endings:  18
# Endings:  17
# Endings:  16
# Endings:  15
# Endings:  14
# Endings:  13
# Endings:  12
# Endings:  11
# Endings:  10
# Endings:  9
# Endings:  8
# Endings:  7
# Endings:  6
# Endings:  5
# Endings:  4
# Endings:  3
# Endings:  2
# Endings:  1
# Endings:  0
# Graph with 2589 nodes and 2442 edges
# C:\Users\Alicja\AppData\Local\Temp\ipykernel_15520\3662378332.py:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(vessel_graph_cn4))

# %%
vessel_graph_cn6 = connect_endings_3d(vessel_graph_cn6, edt_img, 30)
print(nx.info(vessel_graph_cn6))
# Out:
# Endings:  309
# Endings:  308
# Endings:  307
# Endings:  306
# Endings:  305
# Endings:  304
# Endings:  303
# Endings:  302
# Endings:  301
# Endings:  300
# Endings:  299
# Endings:  298
# Endings:  297
# Endings:  296
# Endings:  295
# Endings:  294
# Endings:  293
# Endings:  292
# Endings:  291
# Endings:  290
# Endings:  289
# Endings:  288
# Endings:  287
# Endings:  286
# Endings:  285
# Endings:  284
# Endings:  283
# Endings:  282
# Endings:  281
# Endings:  280
# Endings:  279
# Endings:  278
# Endings:  277
# Endings:  276
# Endings:  275
# Endings:  274
# Endings:  273
# Endings:  272
# Endings:  271
# Endings:  270
# Endings:  269
# Endings:  268
# Endings:  267
# Endings:  266
# Endings:  265
# Endings:  264
# Endings:  263
# Endings:  262
# Endings:  261
# Endings:  260
# Endings:  259
# Endings:  258
# Endings:  257
# Endings:  256
# Endings:  255
# Endings:  254
# Endings:  253
# Endings:  252
# Endings:  251
# Endings:  250
# Endings:  249
# Endings:  248
# Endings:  247
# Endings:  246
# Endings:  245
# Endings:  244
# Endings:  243
# Endings:  242
# Endings:  241
# Endings:  240
# Endings:  239
# Endings:  238
# Endings:  237
# Endings:  236
# Endings:  235
# Endings:  234
# Endings:  233
# Endings:  232
# Endings:  231
# Endings:  230
# Endings:  229
# Endings:  228
# Endings:  227
# Endings:  226
# Endings:  225
# Endings:  224
# Endings:  223
# Endings:  222
# Endings:  221
# Endings:  220
# Endings:  219
# Endings:  218
# Endings:  217
# Endings:  216
# Endings:  215
# Endings:  214
# Endings:  213
# Endings:  212
# Endings:  211
# Endings:  210
# Endings:  209
# Endings:  208
# Endings:  207
# Endings:  206
# Endings:  205
# Endings:  204
# Endings:  203
# Endings:  202
# Endings:  201
# Endings:  200
# Endings:  199
# Endings:  198
# Endings:  197
# Endings:  196
# Endings:  195
# Endings:  194
# Endings:  193
# Endings:  192
# Endings:  191
# Endings:  190
# Endings:  189
# Endings:  188
# Endings:  187
# Endings:  186
# Endings:  185
# Endings:  184
# Endings:  183
# Endings:  182
# Endings:  181
# Endings:  180
# Endings:  179
# Endings:  178
# Endings:  177
# Endings:  176
# Endings:  175
# Endings:  174
# Endings:  173
# Endings:  172
# Endings:  171
# Endings:  170
# Endings:  169
# Endings:  168
# Endings:  167
# Endings:  166
# Endings:  165
# Endings:  164
# Endings:  163
# Endings:  162
# Endings:  161
# Endings:  160
# Endings:  159
# Endings:  158
# Endings:  157
# Endings:  156
# Endings:  155
# Endings:  154
# Endings:  153
# Endings:  152
# Endings:  151
# Endings:  150
# Endings:  149
# Endings:  148
# Endings:  147
# Endings:  146
# Endings:  145
# Endings:  144
# Endings:  143
# Endings:  142
# Endings:  141
# Endings:  140
# Endings:  139
# Endings:  138
# Endings:  137
# Endings:  136
# Endings:  135
# Endings:  134
# Endings:  133
# Endings:  132
# Endings:  131
# Endings:  130
# Endings:  129
# Endings:  128
# Endings:  127
# Endings:  126
# Endings:  125
# Endings:  124
# Endings:  123
# Endings:  122
# Endings:  121
# Endings:  120
# Endings:  119
# Endings:  118
# Endings:  117
# Endings:  116
# Endings:  115
# Endings:  114
# Endings:  113
# Endings:  112
# Endings:  111
# Endings:  110
# Endings:  109
# Endings:  108
# Endings:  107
# Endings:  106
# Endings:  105
# Endings:  104
# Endings:  103
# Endings:  102
# Endings:  101
# Endings:  100
# Endings:  99
# Endings:  98
# Endings:  97
# Endings:  96
# Endings:  95
# Endings:  94
# Endings:  93
# Endings:  92
# Endings:  91
# Endings:  90
# Endings:  89
# Endings:  88
# Endings:  87
# Endings:  86
# Endings:  85
# Endings:  84
# Endings:  83
# Endings:  82
# Endings:  81
# Endings:  80
# Endings:  79
# Endings:  78
# Endings:  77
# Endings:  76
# Endings:  75
# Endings:  74
# Endings:  73
# Endings:  72
# Endings:  71
# Endings:  70
# Endings:  69
# Endings:  68
# Endings:  67
# Endings:  66
# Endings:  65
# Endings:  64
# Endings:  63
# Endings:  62
# Endings:  61
# Endings:  60
# Endings:  59
# Endings:  58
# Endings:  57
# Endings:  56
# Endings:  55
# Endings:  54
# Endings:  53
# Endings:  52
# Endings:  51
# Endings:  50
# Endings:  49
# Endings:  48
# Endings:  47
# Endings:  46
# Endings:  45
# Endings:  44
# Endings:  43
# Endings:  42
# Endings:  41
# Endings:  40
# Endings:  39
# Endings:  38
# Endings:  37
# Endings:  36
# Endings:  35
# Endings:  34
# Endings:  33
# Endings:  32
# Endings:  31
# Endings:  30
# Endings:  29
# Endings:  28
# Endings:  27
# Endings:  26
# Endings:  25
# Endings:  24
# Endings:  23
# Endings:  22
# Endings:  21
# Endings:  20
# Endings:  19
# Endings:  18
# Endings:  17
# Endings:  16
# Endings:  15
# Endings:  14
# Endings:  13
# Endings:  12
# Endings:  11
# Endings:  10
# Endings:  9
# Endings:  8
# Endings:  7
# Endings:  6
# Endings:  5
# Endings:  4
# Endings:  3
# Endings:  2
# Endings:  1
# Endings:  0
# Graph with 2589 nodes and 2587 edges
# C:\Users\Alicja\AppData\Local\Temp\ipykernel_15520\2640228320.py:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(vessel_graph_cn6))

# %%
components = nx.connected_components(vessel_graph_cn6)
largest_component = max(components, key=len)

G_largest = nx.Graph()
for node in largest_component:
    # add the node
    G_largest.add_node(node)
    # add all the edges that connect to the node within the largest component
    for neighbor in vessel_graph_cn6.neighbors(node):
        if neighbor in largest_component:
            G_largest.add_edge(node, neighbor)

# %%
model_with_graph = draw_graph_on_model(bin_reco_small, G_largest)
ColorMapVisualizer(model_with_graph.astype(np.uint8)).visualize()

# %%
plot_3d_graph(vessel_graph_cn)

# %%
pickle.dump(vessel_graph_cn, open('connected-small-2.pickle', 'wb'))

# %%
# %%time
data_graph = parametrize_graph(vessel_graph_cn, edt_img)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 27.2 ms
# C:\Users\Alicja\AppData\Local\Temp\ipykernel_19252\2562224156.py:380: RuntimeWarning: invalid value encountered in divide
#   v1 /= np.linalg.norm(v1)
# C:\Users\Alicja\AppData\Local\Temp\ipykernel_19252\2562224156.py:382: RuntimeWarning: invalid value encountered in divide
#   v2 /= np.linalg.norm(v2)

# %%
plot_3d_graph(data_graph)

# %%
pickle.dump(data_graph, open('parametrized.pickle', 'wb'))

# %%
# %%time
data_graph_cl = clean_data_graph(data_graph)
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms

# %%
plot_3d_graph(data_graph_cl)

# %%
import pickle

# %%
pickle.dump(data_graph_cl, open('cleaned.pickle', 'wb'))

# %%
plot_3d_graph(read_from)

# %%
model_with_graph = draw_graph_on_model(bin_reco_small, vessel_graph_cn)

# %%
ColorMapVisualizer(model_with_graph.astype(np.uint8)).visualize()

# %%
# %%time 
G_complete = nx.complete_graph(H)
# Out:
# CPU times: total: 1min
# Wall time: 1min 1s

# %%
g = pickle.load(open("vessel_graph_remote_1.pickle", "rb"))

# %%
nx.info(vessel_graph3)
# Out:
# C:\Users\Alicja\AppData\Local\Temp\ipykernel_15520\1524500717.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(vessel_graph3)
# 'Graph with 2012 nodes and 140 edges'

# %%
# %%time
vessel_graph_mst = connect_endings_3d(vessel_graph3, edt_img, 5)
# Out:
# CPU times: total: 22.1 s
# Wall time: 22.1 s

# %%
model_with_graph = draw_graph_on_model(bin_reco_small, vessel_graph_mst)
ColorMapVisualizer(model_with_graph.astype(np.uint8)).visualize()

# %%
np.argmax(edt_img)
# Out:
# 17465272

# %%
root = np.unravel_index(np.argmax(edt_img), edt_img.shape)

# %%
max_coord
# Out:
# (349, 179, 232)
